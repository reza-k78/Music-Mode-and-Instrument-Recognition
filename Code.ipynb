# %% [markdown]
# # **Preprocessing & Feature Selection**

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from IPython.display import Audio
import librosa
import librosa.display
import glob
from scipy.io.wavfile import write

# %%
d0I0 = glob.glob("/content/drive/MyDrive/Final Project/D_0/I_0/*")
d0I1 = glob.glob("/content/drive/MyDrive/Final Project/D_0/I_1/*")
d0I2 = glob.glob("/content/drive/MyDrive/Final Project/D_0/I_2/*")
d0I3 = glob.glob("/content/drive/MyDrive/Final Project/D_0/I_3/*")
d0I4 = glob.glob("/content/drive/MyDrive/Final Project/D_0/I_4/*")
d0I5 = glob.glob("/content/drive/MyDrive/Final Project/D_0/I_5/*")
# ------------------------------------------------------------------------------------------------------------------
d1I0 = glob.glob("/content/drive/MyDrive/Final Project/D_1/I_0/*")
d1I1 = glob.glob("/content/drive/MyDrive/Final Project/D_1/I_1/*")
d1I2 = glob.glob("/content/drive/MyDrive/Final Project/D_1/I_2/*")
d1I3 = glob.glob("/content/drive/MyDrive/Final Project/D_1/I_3/*")
d1I4 = glob.glob("/content/drive/MyDrive/Final Project/D_1/I_4/*")
d1I5 = glob.glob("/content/drive/MyDrive/Final Project/D_1/I_5/*")
# ---------------------------------------------------------------------------------------------------------------------
d2I0 = glob.glob("/content/drive/MyDrive/Final Project/D_2/I_0/*")
d2I1 = glob.glob("/content/drive/MyDrive/Final Project/D_2/I_1/*")
d2I2 = glob.glob("/content/drive/MyDrive/Final Project/D_2/I_2/*")
d2I3 = glob.glob("/content/drive/MyDrive/Final Project/D_2/I_3/*")
d2I4 = glob.glob("/content/drive/MyDrive/Final Project/D_2/I_4/*")
d2I5 = glob.glob("/content/drive/MyDrive/Final Project/D_2/I_5/*")
# ---------------------------------------------------------------------------------------------------------------------
d3I0 = glob.glob("/content/drive/MyDrive/Final Project/D_3/I_0/*")
d3I1 = glob.glob("/content/drive/MyDrive/Final Project/D_3/I_1/*")
d3I2 = glob.glob("/content/drive/MyDrive/Final Project/D_3/I_2/*")
d3I3 = glob.glob("/content/drive/MyDrive/Final Project/D_3/I_3/*")
d3I4 = glob.glob("/content/drive/MyDrive/Final Project/D_3/I_4/*")
d3I5 = glob.glob("/content/drive/MyDrive/Final Project/D_3/I_5/*")
# ------------------------------------------------------------------------------------------------------------------------
d4I0 = glob.glob("/content/drive/MyDrive/Final Project/D_4/I_0/*")
d4I1 = glob.glob("/content/drive/MyDrive/Final Project/D_4/I_1/*")
d4I2 = glob.glob("/content/drive/MyDrive/Final Project/D_4/I_2/*")
d4I3 = glob.glob("/content/drive/MyDrive/Final Project/D_4/I_3/*")
d4I4 = glob.glob("/content/drive/MyDrive/Final Project/D_4/I_4/*")
d4I5 = glob.glob("/content/drive/MyDrive/Final Project/D_4/I_5/*")
# --------------------------------------------------------------------------------------------------------------------
d5I0 = glob.glob("/content/drive/MyDrive/Final Project/D_5/I_0/*")
d5I1 = glob.glob("/content/drive/MyDrive/Final Project/D_5/I_1/*")
d5I2 = glob.glob("/content/drive/MyDrive/Final Project/D_5/I_2/*")
d5I3 = glob.glob("/content/drive/MyDrive/Final Project/D_5/I_3/*")
d5I4 = glob.glob("/content/drive/MyDrive/Final Project/D_5/I_4/*")
d5I5 = glob.glob("/content/drive/MyDrive/Final Project/D_5/I_5/*")
# ----------------------------------------------------------------------------------------------------------------------
d6I0 = glob.glob("/content/drive/MyDrive/Final Project/D_6/I_0/*")
d6I1 = glob.glob("/content/drive/MyDrive/Final Project/D_6/I_1/*")
d6I2 = glob.glob("/content/drive/MyDrive/Final Project/D_6/I_2/*")
d6I3 = glob.glob("/content/drive/MyDrive/Final Project/D_6/I_3/*")
d6I4 = glob.glob("/content/drive/MyDrive/Final Project/D_6/I_4/*")
d6I5 = glob.glob("/content/drive/MyDrive/Final Project/D_6/I_5/*")

# %%
D0 = d0I0 + d0I1 + d0I2 + d0I3 + d0I4 + d0I5
I0 = list(np.ones(len(d0I0))*0) + list(np.ones(len(d0I1))*1) + list(np.ones(len(d0I2))*2) + list(np.ones(len(d0I3))*3) + list(np.ones(len(d0I4))*4) + list(np.ones(len(d0I5))*5)
D1 = d1I0 + d1I1 + d1I2 + d1I3 + d1I4 + d1I5
I1 = list(np.ones(len(d1I0))*0) + list(np.ones(len(d1I1))*1) + list(np.ones(len(d1I2))*2) + list(np.ones(len(d1I3))*3) + list(np.ones(len(d1I4))*4) + list(np.ones(len(d1I5))*5)
D2 = d2I0 + d2I1 + d2I2 + d2I3 + d2I4 + d2I5
I2 = list(np.ones(len(d2I0))*0) + list(np.ones(len(d2I1))*1) + list(np.ones(len(d2I2))*2) + list(np.ones(len(d2I3))*3) + list(np.ones(len(d2I4))*4) + list(np.ones(len(d2I5))*5)
D3 = d3I0 + d3I1 + d3I2 + d3I3 + d3I4 + d3I5
I3 = list(np.ones(len(d3I0))*0) + list(np.ones(len(d3I1))*1) + list(np.ones(len(d3I2))*2) + list(np.ones(len(d3I3))*3) + list(np.ones(len(d3I4))*4) + list(np.ones(len(d3I5))*5)
D4 = d4I0 + d4I1 + d4I2 + d4I3 + d4I4 + d4I5
I4 = list(np.ones(len(d4I0))*0) + list(np.ones(len(d4I1))*1) + list(np.ones(len(d4I2))*2) + list(np.ones(len(d4I3))*3) + list(np.ones(len(d4I4))*4) + list(np.ones(len(d4I5))*5)
D5 = d5I0 + d5I1 + d5I2 + d5I3 + d5I4 + d5I5
I5 = list(np.ones(len(d5I0))*0) + list(np.ones(len(d5I1))*1) + list(np.ones(len(d5I2))*2) + list(np.ones(len(d5I3))*3) + list(np.ones(len(d5I4))*4) + list(np.ones(len(d5I5))*5)
D6 = d6I0 + d6I1 + d6I2 + d6I3 + d6I4 + d6I5
I6 = list(np.ones(len(d6I0))*0) + list(np.ones(len(d6I1))*1) + list(np.ones(len(d6I2))*2) + list(np.ones(len(d6I3))*3) + list(np.ones(len(d6I4))*4) + list(np.ones(len(d6I5))*5)

D = D0 + D1 + D2 + D3 + D4 + D5 + D6
I = I0 + I1 + I2 + I3 + I4 + I5 + I6

DL = list(np.ones(len(D0))*0) + list(np.ones(len(D1))*1) + list(np.ones(len(D2))*2) + list(np.ones(len(D3))*3) + list(np.ones(len(D4))*4) + list(np.ones(len(D5))*5) + list(np.ones(len(D6))*6)

# %%
DF = pd.DataFrame({"file path":D,
                   "Instrument":I,
                   "Dastgah":DL})
DF
# Out:
#                                              file path  Instrument  Dastgah
# 0    /content/drive/MyDrive/Final Project/D_0/I_0/F...         0.0      0.0
# 1    /content/drive/MyDrive/Final Project/D_0/I_0/K...         0.0      0.0
# 2    /content/drive/MyDrive/Final Project/D_0/I_0/4...         0.0      0.0
# 3    /content/drive/MyDrive/Final Project/D_0/I_0/4...         0.0      0.0
# 4    /content/drive/MyDrive/Final Project/D_0/I_0/5...         0.0      0.0
# ..                                                 ...         ...      ...
# 950  /content/drive/MyDrive/Final Project/D_6/I_5/i...         5.0      6.0
# 951  /content/drive/MyDrive/Final Project/D_6/I_5/i...         5.0      6.0
# 952  /content/drive/MyDrive/Final Project/D_6/I_5/i...         5.0      6.0
# 953  /content/drive/MyDrive/Final Project/D_6/I_5/i...         5.0      6.0
# 954  /content/drive/MyDrive/Final Project/D_6/I_5/i...         5.0      6.0
#
# [955 rows x 3 columns]

# %%
def creat(DF):
  samples = []
  files = []
  chroma_cens0 = []
  chroma_cens1 = []
  chroma_cens2 = []
  chroma_cens3 = []
  chroma_cens4 = []
  chroma_cens5 = []
  chroma_cens6 = []
  chroma_cens7 = []
  chroma_cens8 = []
  chroma_cens9 = []
  chroma_cens10 = []
  chroma_cens11 = []
  chroma_cens12 = []
  chroma_cens13 = []
  chroma_cens14 = []
  chroma_cens15 = []
  chroma_cens16 = []
  chroma_cens17 = []
  chroma_cens18 = []
  chroma_cens19 = []
  chroma_stft = []
  chroma_cqt0 = []
  chroma_cqt1 = []
  chroma_cqt2 = []
  chroma_cqt3 = []
  chroma_cqt4 = []
  chroma_cqt5 = []
  chroma_cqt6 = []
  chroma_cqt7 = []
  chroma_cqt8 = []
  chroma_cqt9 = []
  chroma_cqt10 = []
  chroma_cqt11 = []
  chroma_cqt12 = []
  chroma_cqt13 = []
  chroma_cqt14 = []
  chroma_cqt15 = []
  chroma_cqt16 = []
  chroma_cqt17 = []
  chroma_cqt18 = []
  chroma_cqt19 = []

  tonnetz0 = []
  tonnetz1 = []
  tonnetz2 = []
  tonnetz3 = []
  tonnetz4 = []
  tonnetz5 = []

  centroid = []
  bw = []
  rolloff = []
  Rms = []
  ZRC = []
  Mel = []
  Mfcc0 = []
  Mfcc1 = []
  Mfcc2 = []
  Mfcc3 = []
  Mfcc4 = []
  Mfcc5 = []
  Mfcc6 = []
  Mfcc7 = []
  Mfcc8 = []
  Mfcc9 = []
  Mfcc10 = []
  Mfcc11 = []
  Mfcc12 = []
  Mfcc13 = []
  Mfcc14 = []
  Mfcc15 = []
  Mfcc16 = []
  Mfcc17 = []
  Mfcc18 = []
  Mfcc19 = []
  Mfcc20 = []
  Mfcc21 = []
  Mfcc22 = []
  Mfcc23 = []

  for f in DF['file path']:
    try:
      audio_array,sr = librosa.load(f, offset=10)
      c_stft = np.mean(librosa.feature.chroma_stft(audio_array, sr, n_chroma=20))
      c_cqt = librosa.feature.chroma_cqt(audio_array, sr, n_chroma=20, bins_per_octave= 60)
      c_cens = librosa.feature.chroma_cens(audio_array, sr , n_chroma=20, bins_per_octave= 60)
      sc = np.mean(librosa.feature.spectral_centroid(audio_array, sr))
      sb = np.mean(librosa.feature.spectral_bandwidth(audio_array, sr))
      srf = np.mean(librosa.feature.spectral_rolloff(audio_array, sr))
      rms = np.mean(librosa.feature.rms(audio_array))
      zrc = np.mean(librosa.feature.zero_crossing_rate(audio_array))
      mfccs = librosa.feature.mfcc(audio_array , sr=sr,  n_mfcc=24)
      mel = np.mean(librosa.feature.melspectrogram (audio_array))
      y = librosa.effects.harmonic(audio_array)
      ton = librosa.feature.tonnetz(y, sr=sr)

      chroma_stft.append(c_stft)
      Mel.append(mel)
      centroid.append(sc)
      bw.append(sb)
      rolloff.append(srf)
      Rms.append(rms)
      ZRC.append(zrc)
      files.append(audio_array)
      samples.append(sr)
    
      chroma_cens0.append(np.mean(c_cens[0]))
      chroma_cens1.append(np.mean(c_cens[1]))
      chroma_cens2.append(np.mean(c_cens[2]))
      chroma_cens3.append(np.mean(c_cens[3]))
      chroma_cens4.append(np.mean(c_cens[4]))
      chroma_cens5.append(np.mean(c_cens[5]))
      chroma_cens6.append(np.mean(c_cens[6]))
      chroma_cens7.append(np.mean(c_cens[7]))
      chroma_cens8.append(np.mean(c_cens[8]))
      chroma_cens9.append(np.mean(c_cens[9]))
      chroma_cens10.append(np.mean(c_cens[10]))
      chroma_cens11.append(np.mean(c_cens[11]))
      chroma_cens12.append(np.mean(c_cens[12]))
      chroma_cens13.append(np.mean(c_cens[13]))
      chroma_cens14.append(np.mean(c_cens[14]))
      chroma_cens15.append(np.mean(c_cens[15]))
      chroma_cens16.append(np.mean(c_cens[16]))
      chroma_cens17.append(np.mean(c_cens[17]))
      chroma_cens18.append(np.mean(c_cens[18]))
      chroma_cens19.append(np.mean(c_cens[19]))

      tonnetz0.append(np.mean(ton[0]))
      tonnetz1.append(np.mean(ton[1]))
      tonnetz2.append(np.mean(ton[2]))
      tonnetz3.append(np.mean(ton[3]))
      tonnetz4.append(np.mean(ton[4]))
      tonnetz5.append(np.mean(ton[5]))

      chroma_cqt0.append(np.mean(c_cqt[0]))
      chroma_cqt1.append(np.mean(c_cqt[1]))
      chroma_cqt2.append(np.mean(c_cqt[2]))
      chroma_cqt3.append(np.mean(c_cqt[3]))
      chroma_cqt4.append(np.mean(c_cqt[4]))
      chroma_cqt5.append(np.mean(c_cqt[5]))
      chroma_cqt6.append(np.mean(c_cqt[6]))
      chroma_cqt7.append(np.mean(c_cqt[7]))
      chroma_cqt8.append(np.mean(c_cqt[8]))
      chroma_cqt9.append(np.mean(c_cqt[9]))
      chroma_cqt10.append(np.mean(c_cqt[10]))
      chroma_cqt11.append(np.mean(c_cqt[11]))
      chroma_cqt12.append(np.mean(c_cqt[12]))
      chroma_cqt13.append(np.mean(c_cqt[13]))
      chroma_cqt14.append(np.mean(c_cqt[14]))
      chroma_cqt15.append(np.mean(c_cqt[15]))
      chroma_cqt16.append(np.mean(c_cqt[16]))
      chroma_cqt17.append(np.mean(c_cqt[17]))
      chroma_cqt18.append(np.mean(c_cqt[18]))
      chroma_cqt19.append(np.mean(c_cqt[19]))

      Mfcc0.append(np.mean(mfccs[0]))
      Mfcc1.append(np.mean(mfccs[1]))
      Mfcc2.append(np.mean(mfccs[2]))
      Mfcc3.append(np.mean(mfccs[3]))
      Mfcc4.append(np.mean(mfccs[4]))
      Mfcc5.append(np.mean(mfccs[5]))
      Mfcc6.append(np.mean(mfccs[6]))
      Mfcc7.append(np.mean(mfccs[7]))
      Mfcc8.append(np.mean(mfccs[8]))
      Mfcc9.append(np.mean(mfccs[9]))
      Mfcc10.append(np.mean(mfccs[10]))
      Mfcc11.append(np.mean(mfccs[11]))
      Mfcc12.append(np.mean(mfccs[12]))
      Mfcc13.append(np.mean(mfccs[13]))
      Mfcc14.append(np.mean(mfccs[14]))
      Mfcc15.append(np.mean(mfccs[15]))
      Mfcc16.append(np.mean(mfccs[16]))
      Mfcc17.append(np.mean(mfccs[17]))
      Mfcc18.append(np.mean(mfccs[18]))
      Mfcc19.append(np.mean(mfccs[19]))
      Mfcc20.append(np.mean(mfccs[20]))
      Mfcc21.append(np.mean(mfccs[21]))
      Mfcc22.append(np.mean(mfccs[22]))
      Mfcc23.append(np.mean(mfccs[23]))
    except:
      print(f'song path :{f}')

  DF['Sample rates'] = samples
  DF['Audios'] = files
  DF['Chroma stft'] = chroma_stft
  DF['Spectral bandwidth'] = sb
  DF['Spectral rolloff'] = rolloff
  DF['Mel Spectogram'] = Mel
  DF['rms'] = Rms
  DF['Zero crossing rate'] = ZRC
  DF['Chroma Cens_0'] = chroma_cens0
  DF['Chroma Cens_1'] = chroma_cens1
  DF['Chroma Cens_2'] = chroma_cens2
  DF['Chroma Cens_3'] = chroma_cens3
  DF['Chroma Cens_4'] = chroma_cens4
  DF['Chroma Cens_5'] = chroma_cens5
  DF['Chroma Cens_6'] = chroma_cens6
  DF['Chroma Cens_7'] = chroma_cens7
  DF['Chroma Cens_8'] = chroma_cens8
  DF['Chroma Cens_9'] = chroma_cens9
  DF['Chroma Cens_10'] = chroma_cens10
  DF['Chroma Cens_11'] = chroma_cens11
  DF['Chroma Cens_12'] = chroma_cens12
  DF['Chroma Cens_13'] = chroma_cens13
  DF['Chroma Cens_14'] = chroma_cens14
  DF['Chroma Cens_15'] = chroma_cens15
  DF['Chroma Cens_16'] = chroma_cens16
  DF['Chroma Cens_17'] = chroma_cens17
  DF['Chroma Cens_18'] = chroma_cens18
  DF['Chroma Cens_19'] = chroma_cens19

  DF['Chroma CQT_0'] = chroma_cqt0
  DF['Chroma CQT_1'] = chroma_cqt1
  DF['Chroma CQT_2'] = chroma_cqt2
  DF['Chroma CQT_3'] = chroma_cqt3
  DF['Chroma CQT_4'] = chroma_cqt4
  DF['Chroma CQT_5'] = chroma_cqt5
  DF['Chroma CQT_6'] = chroma_cqt6
  DF['Chroma CQT_7'] = chroma_cqt7
  DF['Chroma CQT_8'] = chroma_cqt8
  DF['Chroma CQT_9'] = chroma_cqt9
  DF['Chroma CQT_10'] = chroma_cqt10
  DF['Chroma CQT_11'] = chroma_cqt11
  DF['Chroma CQT_12'] = chroma_cqt12
  DF['Chroma CQT_13'] = chroma_cqt13
  DF['Chroma CQT_14'] = chroma_cqt14
  DF['Chroma CQT_15'] = chroma_cqt15
  DF['Chroma CQT_16'] = chroma_cqt16
  DF['Chroma CQT_17'] = chroma_cqt17
  DF['Chroma CQT_18'] = chroma_cqt18
  DF['Chroma CQT_19'] = chroma_cqt19
  
  DF['Tonnetz_0'] = tonnetz0
  DF['Tonnetz_1'] = tonnetz1
  DF['Tonnetz_2'] = tonnetz2
  DF['Tonnetz_3'] = tonnetz3
  DF['Tonnetz_4'] = tonnetz4
  DF['Tonnetz_5'] = tonnetz5

  DF['MFCC_0'] = Mfcc0
  DF['MFCC_1'] = Mfcc1
  DF['MFCC_2'] = Mfcc2
  DF['MFCC_3'] = Mfcc3
  DF['MFCC_4'] = Mfcc4
  DF['MFCC_5'] = Mfcc5
  DF['MFCC_6'] = Mfcc6
  DF['MFCC_7'] = Mfcc7
  DF['MFCC_8'] = Mfcc8
  DF['MFCC_9'] = Mfcc9
  DF['MFCC_10'] = Mfcc10
  DF['MFCC_11'] = Mfcc11
  DF['MFCC_12'] = Mfcc12
  DF['MFCC_13'] = Mfcc13
  DF['MFCC_14'] = Mfcc14
  DF['MFCC_15'] = Mfcc15
  DF['MFCC_16'] = Mfcc16
  DF['MFCC_17'] = Mfcc17
  DF['MFCC_18'] = Mfcc18
  DF['MFCC_19'] = Mfcc19
  DF['MFCC_20'] = Mfcc20
  DF['MFCC_21'] = Mfcc21
  DF['MFCC_22'] = Mfcc22
  DF['MFCC_23'] = Mfcc23

  return DF

# %%
DF1 = creat (DF[:100])
DF1.to_csv('A1.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ...

# %%
DF2 = creat (DF[100:200])
DF2.to_csv('A2.csv', header='False')
# Out:
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ...

# %%
DF3 = creat (DF[200:300])
DF3.to_csv('A3.csv', header='False')
# Out:
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ...

# %%
DF4 = creat (DF[300:400])
DF4.to_csv('A4.csv', header='False')
# Out:
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ...

# %%
DF5 = creat (DF[400:500])
DF5.to_csv('A5.csv', header='False')
# Out:
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ...

# %%
DF6 = creat (DF[500:600])
DF6.to_csv('A6.csv', header='False')
# Out:
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ...

# %%
DF7 = creat (DF[600:700])
DF7.to_csv('A7.csv', header='False')
# Out:
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ...

# %%
DF8 = creat (DF[700:800])
DF8.to_csv('A8.csv', header='False')
# Out:
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ...

# %%
DF9 = creat (DF[800:900])
DF9.to_csv('A9.csv', header='False')
# Out:
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ...

# %%
DF10 = creat (DF[900:])
DF10.to_csv('A10.csv', header='False')
# Out:
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ...

# %%
a1 = pd.read_csv('/content/A1.csv')
a2 = pd.read_csv('/content/A2.csv')
a3 = pd.read_csv('/content/A3.csv')
a4 = pd.read_csv('/content/A4.csv')
a5 = pd.read_csv('/content/A5.csv')
a6 = pd.read_csv('/content/A6.csv')
a7 = pd.read_csv('/content/A7.csv')
a8 = pd.read_csv('/content/A8.csv')
a9 = pd.read_csv('/content/A9.csv')
a10 = pd.read_csv('/content/A10.csv')

# %% [markdown]
# # **PCA**

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
data = [a1, a2, a3, a4, a5, a6, a7, a8, a9, a10] 
df = pd.concat(data)
df = df.drop('Unnamed: 0', axis=1)
df = df.reset_index()
df = df.drop('index', axis=1)
d = df.drop('Audios', axis=1)
d = d.drop('Sample rates' ,axis=1)
d = d.drop('Dastgah' ,axis=1)
d = d.drop('Instrument', axis=1) 
d = d.drop('file path', axis=1)

# %%
scaler = StandardScaler()
scaler.fit(d)
scaled_data = scaler.transform(d)
pca = PCA()
pca.fit(scaled_data)
x_pca = pca.transform(scaled_data)
y = df['Dastgah']

# %%
# we dont use PCA in this project because Condition Number isn't too large
Cond_Num = pca.explained_variance_[0]/pca.explained_variance_[-1]
Cond_Num
# Out:
# 3290.522473456759

# %%
pca.explained_variance_

# %%
pca.explained_variance_ratio_

# %%
fig = plt.figure(figsize = (16, 9))
ax = plt.axes(projection ="3d")
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.4, alpha = 0.2)
cmap1 = plt.get_cmap('Set1')
s = ax.scatter3D(x_pca.T[0], x_pca.T[1], x_pca.T[2],
                    alpha = 1,
                    c = y,
                    cmap = cmap1,
                    marker ='^')
 
plt.title("PCA")
ax.set_xlabel('X', fontweight ='bold')
ax.set_ylabel('Y', fontweight ='bold')
ax.set_zlabel('Z', fontweight ='bold')
fig.colorbar(s, ax = ax, shrink = 0.5, aspect = 5)
plt.show()

# %%
fig = plt.figure(figsize = (16, 9))
ax = plt.axes()
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.4, alpha = 0.2)
cmap1 = plt.get_cmap('Set1')
s = ax.scatter(x_pca.T[0], x_pca.T[1],
                    alpha = 1,
                    c = y,
                    cmap = cmap1,
                    marker ='^')
 
plt.title("PCA")
ax.set_xlabel('X', fontweight ='bold')
ax.set_ylabel('Y', fontweight ='bold')
fig.colorbar(s, ax = ax, shrink = 0.5, aspect = 5)
plt.show()

# %% [markdown]
# # **LDA**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# %%
data = [a1, a2, a3, a4, a5, a6, a7, a8, a9, a10] 
df = pd.concat(data)
df = df.drop('Unnamed: 0', axis=1)
df = df.reset_index()
df = df.drop('index', axis=1)
d = df.drop('Audios', axis=1)
d = d.drop('Sample rates' ,axis=1)
d = d.drop('Instrument', axis=1) 
d = d.drop('file path', axis=1)

# %%
y = d['Dastgah'][:]
X = d.iloc[: , 1:].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=5)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
lda = LDA()
X_train_lda = lda.fit_transform(X_train, y_train)
X_test_lda = lda.transform(X_test)

# %%
pd.DataFrame(X_train_lda).head()

# %%
fig = plt.figure(figsize = (16, 9))
ax = plt.axes(projection ="3d")
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.4, alpha = 0.2)
cmap1 = plt.get_cmap('Set1')
s = ax.scatter3D(X_train_lda.T[0], X_train_lda.T[1], X_train_lda.T[2],
                    alpha = 1,
                    c = y_train,
                    cmap = cmap1,
                    marker ='^')
 
plt.title("LDA")
ax.set_xlabel('X', fontweight ='bold')
ax.set_ylabel('Y', fontweight ='bold')
ax.set_zlabel('Z', fontweight ='bold')
fig.colorbar(s, ax = ax, shrink = 0.5, aspect = 5)
plt.show()

# %%
fig = plt.figure(figsize = (16, 9))
ax = plt.axes()
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.4, alpha = 0.2)
cmap1 = plt.get_cmap('Set1')
s = ax.scatter(X_train_lda.T[0], X_train_lda.T[1],
                    alpha = 1,
                    c = y_train,
                    cmap = cmap1,
                    marker ='^')
 
plt.title("LDA")
ax.set_xlabel('X', fontweight ='bold')
ax.set_ylabel('Y', fontweight ='bold')

fig.colorbar(s, ax = ax, shrink = 0.5, aspect = 5)
plt.show()

# %% [markdown]
# # **Classification**

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from matplotlib import pyplot as plt
from sklearn import metrics
from sklearn.metrics import jaccard_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score ,auc 
from sklearn.metrics import roc_curve
from sklearn.metrics import accuracy_score
from yellowbrick.classifier import ConfusionMatrix
from yellowbrick.classifier import ROCAUC
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
# without LDA
# Standarded
data = [a1, a2, a3, a4, a5, a6, a7, a8, a9, a10] 
df = pd.concat(data)
df = df.drop('Unnamed: 0', axis=1)
df = df.reset_index()
df = df.drop('index', axis=1)
d = df.drop('Audios', axis=1)
d = d.drop('Sample rates' ,axis=1)
d = d.drop('Instrument', axis=1) 
d = d.drop('file path', axis=1)
y = d['Dastgah'][:]
X = d.iloc[: , 1:].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=5)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# without LDA
# without Standardization
data = [a1, a2, a3, a4, a5, a6, a7, a8, a9, a10] 
df = pd.concat(data)
df = df.drop('Unnamed: 0', axis=1)
df = df.reset_index()
df = df.drop('index', axis=1)
d = df.drop('Audios', axis=1)
d = d.drop('Sample rates' ,axis=1)
d = d.drop('Instrument', axis=1) 
d = d.drop('file path', axis=1)
y = d['Dastgah'][:]
X = d.iloc[: , 1:].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=5)

# %%
pd.DataFrame(X_train)

# %%
# SVM Poly
clf = sklearn.svm.SVC(kernel='poly',gamma='auto',decision_function_shape='ovr', degree =3)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)


print("\nThe accuracy of the model is: %.1f%%" % (accuracy_score(y_test, y_pred)*100))
print("\nThe Error of the model is: %.1f%%" % (100-(accuracy_score(y_test, y_pred)*100)))
print(classification_report(y_test, y_pred, target_names=['0', '1', '2', '3', '4', '5', '6']))

# print("\nConfusion Matrix is :")
cnf_matrix= metrics.confusion_matrix(y_test, y_pred)
# print(cnf_matrix)

m = ConfusionMatrix(clf, classes=['0', '1', '2', '3', '4', '5', '6'])
m.fit(X_train, y_train)
m.score(X_test, y_test)
m.show()

visualizer = ROCAUC(clf, classes=['0', '1', '2', '3', '4', '5', '6'])
visualizer.fit(X_train, y_train)        
visualizer.score(X_test, y_test)        
visualizer.show()
# Out:
# The accuracy of the model is: 56.1%
#
# The Error of the model is: 43.9%
#               precision    recall  f1-score   support
#
#            0       0.62      0.75      0.68        20
#            1       0.45      0.43      0.44        30
#            2       0.54      0.61      0.57        36
#            3       0.76      0.53      0.62        53
#            4       0.45      0.83      0.59        30
#            5       0.62      0.45      0.53        33
#            6       0.55      0.43      0.48        37
#
#     accuracy                           0.56       239
#    macro avg       0.57      0.58      0.56       239
# weighted avg       0.59      0.56      0.56       239

# %%
# SVM Rbf
clf = sklearn.svm.SVC(kernel='rbf',gamma='auto',decision_function_shape='ovr')
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)


print("\nThe accuracy of the model is: %.1f%%" % (accuracy_score(y_test, y_pred)*100))
print("\nThe Error of the model is: %.1f%%" % (100-(accuracy_score(y_test, y_pred)*100)))
print(classification_report(y_test, y_pred, target_names=['0', '1', '2', '3', '4', '5', '6']))

# print("\nConfusion Matrix is :")
cnf_matrix= metrics.confusion_matrix(y_test, y_pred)
# print(cnf_matrix)

m = ConfusionMatrix(clf, classes=['0', '1', '2', '3', '4', '5', '6'])
m.fit(X_train, y_train)
m.score(X_test, y_test)
m.show()

visualizer = ROCAUC(clf, classes=['0', '1', '2', '3', '4', '5', '6'])
visualizer.fit(X_train, y_train)        
visualizer.score(X_test, y_test)        
visualizer.show()
# Out:
# The accuracy of the model is: 59.8%
#
# The Error of the model is: 40.2%
#               precision    recall  f1-score   support
#
#            0       0.65      0.75      0.70        20
#            1       0.46      0.53      0.49        30
#            2       0.57      0.69      0.62        36
#            3       0.73      0.60      0.66        53
#            4       0.58      0.60      0.59        30
#            5       0.67      0.55      0.60        33
#            6       0.54      0.51      0.53        37
#
#     accuracy                           0.60       239
#    macro avg       0.60      0.61      0.60       239
# weighted avg       0.61      0.60      0.60       239

# %%
# SVM linear
clf = sklearn.svm.SVC(kernel='linear',gamma='auto',decision_function_shape='ovr', degree= 1)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print("\nThe accuracy of the model is: %.1f%%" % (accuracy_score(y_test, y_pred)*100))
print("\nThe Error of the model is: %.1f%%" % (100-(accuracy_score(y_test, y_pred)*100)))
print(classification_report(y_test, y_pred, target_names=['0', '1', '2', '3', '4', '5', '6']))

# print("\nConfusion Matrix is :")
cnf_matrix= metrics.confusion_matrix(y_test, y_pred)
# print(cnf_matrix)

m = ConfusionMatrix(clf, classes=['0', '1', '2', '3', '4', '5', '6'])
m.fit(X_train, y_train)
m.score(X_test, y_test)
m.show()

visualizer = ROCAUC(clf, classes=['0', '1', '2', '3', '4', '5', '6'])
visualizer.fit(X_train, y_train)        
visualizer.score(X_test, y_test)        
visualizer.show()
# Out:
# The accuracy of the model is: 56.5%
#
# The Error of the model is: 43.5%
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        20
#            1       0.56      0.50      0.53        30
#            2       0.50      0.67      0.57        36
#            3       0.70      0.60      0.65        53
#            4       0.52      0.57      0.54        30
#            5       0.53      0.48      0.51        33
#            6       0.46      0.43      0.44        37
#
#     accuracy                           0.56       239
#    macro avg       0.57      0.57      0.57       239
# weighted avg       0.57      0.56      0.56       239

# %%
# MLP
clf = MLPClassifier(max_iter=15, early_stopping=True, learning_rate_init=0.001, 
                  validation_fraction=0.05,
                  verbose=False, hidden_layer_sizes=(512,256, 256, 512))
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print("\nThe accuracy of the model is: %.1f%%" % (accuracy_score(y_test, y_pred)*100))
print("\nThe Error of the model is: %.1f%%" % (100-(accuracy_score(y_test, y_pred)*100)))
print(classification_report(y_test, y_pred, target_names=['0', '1', '2', '3', '4', '5', '6']))

# print("\nConfusion Matrix is :")
cnf_matrix= metrics.confusion_matrix(y_test, y_pred)
# print(cnf_matrix)

m = ConfusionMatrix(clf, classes=['0', '1', '2', '3', '4', '5', '6'])
m.fit(X_train, y_train)
m.score(X_test, y_test)
m.show()

visualizer = ROCAUC(clf, classes=['0', '1', '2', '3', '4', '5', '6'])
visualizer.fit(X_train, y_train)        
visualizer.score(X_test, y_test)        
visualizer.show()

plt.plot(clf.loss_curve_, label="Loss Curve")
plt.plot(clf.validation_scores_, label="Validation Score")
plt.legend()
plt.ylabel("loss/score")
plt.xlabel("iteration")
plt.title("MLP")
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (15) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# 1 Nearest Neighbor

clf = KNeighborsClassifier(1)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print("\nThe accuracy of the model is: %.1f%%" % (accuracy_score(y_test, y_pred)*100))
print("\nThe Error of the model is: %.1f%%" % (100-(accuracy_score(y_test, y_pred)*100)))
print(classification_report(y_test, y_pred, target_names=['0', '1', '2', '3', '4', '5', '6']))

# print("\nConfusion Matrix is :")
cnf_matrix= metrics.confusion_matrix(y_test, y_pred)
# print(cnf_matrix)

m = ConfusionMatrix(clf, classes=['0', '1', '2', '3', '4', '5', '6'])
m.fit(X_train, y_train)
m.score(X_test, y_test)
m.show()

visualizer = ROCAUC(clf, classes=['0', '1', '2', '3', '4', '5', '6'])
visualizer.fit(X_train, y_train)        
visualizer.score(X_test, y_test)        
visualizer.show()
# Out:
# The accuracy of the model is: 65.7%
#
# The Error of the model is: 34.3%
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87        20
#            1       0.64      0.70      0.67        30
#            2       0.59      0.67      0.62        36
#            3       0.83      0.72      0.77        53
#            4       0.58      0.63      0.60        30
#            5       0.50      0.48      0.49        33
#            6       0.63      0.59      0.61        37
#
#     accuracy                           0.66       239
#    macro avg       0.66      0.66      0.66       239
# weighted avg       0.66      0.66      0.66       239

# %%
# Random Forest
clf = RandomForestClassifier(max_depth=50 ,n_estimators = 700)  
clf.fit(X_train, y_train) 
y_pred = clf.predict(X_test)
print("\nThe accuracy of the model is: %.1f%%" % (accuracy_score(y_test, y_pred)*100))
print("\nThe Error of the model is: %.1f%%" % (100-(accuracy_score(y_test, y_pred)*100)))
print(classification_report(y_test, y_pred, target_names=['0', '1', '2', '3', '4', '5', '6']))

# print("\nConfusion Matrix is :")
cnf_matrix= metrics.confusion_matrix(y_test, y_pred)
# print(cnf_matrix)

m = ConfusionMatrix(clf, classes=['0', '1', '2', '3', '4', '5', '6'])
m.fit(X_train, y_train)
m.score(X_test, y_test)
m.show()

visualizer = ROCAUC(clf, classes=['0', '1', '2', '3', '4', '5', '6'])
visualizer.fit(X_train, y_train)        
visualizer.score(X_test, y_test)        
visualizer.show()
# Out:
# The accuracy of the model is: 82.0%
#
# The Error of the model is: 18.0%
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        20
#            1       0.77      0.77      0.77        30
#            2       0.74      0.86      0.79        36
#            3       0.87      0.91      0.89        53
#            4       0.70      0.70      0.70        30
#            5       0.92      0.67      0.77        33
#            6       0.84      0.86      0.85        37
#
#     accuracy                           0.82       239
#    macro avg       0.83      0.82      0.82       239
# weighted avg       0.83      0.82      0.82       239

# %% [markdown]
# # **Clustering**

# %%
from sklearn import metrics
import seaborn as sns
from sklearn.cluster import KMeans , AgglomerativeClustering
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import linkage,dendrogram,fcluster

# %%
data = [a1, a2, a3, a4, a5, a6, a7, a8, a9, a10] 
df = pd.concat(data)
df = df.drop('Unnamed: 0', axis=1)
df = df.reset_index()
df = df.drop('index', axis=1)
d = df.drop('Audios', axis=1)
d = d.drop('Sample rates' ,axis=1)
d = d.drop('Instrument', axis=1) 
d = d.drop('file path', axis=1)
y = d['Dastgah'][:]
X = d.iloc[: , 1:].values

# %%
# K means
inertias = []

for i in range(1,21):
    kmeans = KMeans(n_clusters=i, n_init=15)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_)

plt.plot(range(1,21), inertias, marker='o')
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
def accuracy(y_true, y_pred):
    accuracy = np.sum(y_true == y_pred) / len(y_true)
    return accuracy*100

# %%
# K = 2 
kmeans = KMeans(n_clusters=2, n_init=1).fit(X)
y_pred=kmeans.predict(X)

print('Adjusted rand score :', metrics.adjusted_rand_score(y, y_pred))
print('Normalized mutual information score :',metrics.normalized_mutual_info_score(y, y_pred))
print('Silhouette score :',metrics.silhouette_score(X, y_pred, metric='euclidean'))
print('Calinski harabasz score :',metrics.calinski_harabasz_score(X, y_pred))
print('Davies bouldin score', metrics.davies_bouldin_score(X, y_pred))
# Out:
# Adjusted rand score : 0.00029793417350528894
# Normalized mutual information score : 0.0027689713833417566
# Silhouette score : 0.46283836393403877
# Calinski harabasz score : 1268.6888337266796
# Davies bouldin score 0.7659539567728815

# %%
fig = plt.figure(figsize = (16, 9))
ax = plt.axes()
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.4, alpha = 0.2)
cmap1 = plt.get_cmap('Set1')
s = ax.scatter(X[:,2], X[:,5],
                    alpha = 1,
                    c = kmeans.labels_,
                    cmap = cmap1,
                    marker ='^')
 
plt.title("K means(K=2)")
ax.set_xlabel('X', fontweight ='bold')
ax.set_ylabel('Y', fontweight ='bold')

fig.colorbar(s, ax = ax, shrink = 0.5, aspect = 5)
plt.show()

# %%
fig = plt.figure(figsize = (16, 9))
ax = plt.axes(projection ="3d")
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.4, alpha = 0.2)
cmap1 = plt.get_cmap('Set1')
s = ax.scatter3D(X[:,2], X[:,5], X[:,1],
                    alpha = 1,
                    c = kmeans.labels_,
                    cmap = cmap1,
                    marker ='^')
 
plt.title("K means(K=2)")
ax.set_xlabel('X', fontweight ='bold')
ax.set_ylabel('Y', fontweight ='bold')
ax.set_zlabel('Z', fontweight ='bold')
fig.colorbar(s, ax = ax, shrink = 0.5, aspect = 5)
plt.show()

# %%
# K=7
kmeans = KMeans(n_clusters=7 , n_init=1).fit(X)
y_pred=kmeans.predict(X)

print('Accuracy of Clustring :' , accuracy(y_pred, y))
print('Adjusted rand score :', metrics.adjusted_rand_score(y, y_pred))
print('Normalized mutual information score :',metrics.normalized_mutual_info_score(y, y_pred))
print('Silhouette score :',metrics.silhouette_score(X, y_pred, metric='euclidean'))
print('Calinski harabasz score :',metrics.calinski_harabasz_score(X, y_pred))
print('Davies bouldin score', metrics.davies_bouldin_score(X, y_pred))
# Out:
# Accuracy of Clustring : 17.06806282722513
# Adjusted rand score : 0.04709592490872545
# Normalized mutual information score : 0.09273636872692492
# Silhouette score : 0.33808683842593507
# Calinski harabasz score : 1207.9008645666897
# Davies bouldin score 0.8844997678841526

# %%
fig = plt.figure(figsize = (16, 9))
ax = plt.axes()
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.4, alpha = 0.2)
cmap1 = plt.get_cmap('Set1')
s = ax.scatter(X[:,2], X[:,5],
                    alpha = 1,
                    c = kmeans.labels_,
                    cmap = cmap1,
                    marker ='^')
 
plt.title("K means(K=7)")
ax.set_xlabel('X', fontweight ='bold')
ax.set_ylabel('Y', fontweight ='bold')

fig.colorbar(s, ax = ax, shrink = 0.5, aspect = 5)
plt.show()

# %%
fig = plt.figure(figsize = (16, 9))
ax = plt.axes(projection ="3d")
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.4, alpha = 0.2)
cmap1 = plt.get_cmap('Set1')
s = ax.scatter3D(X[:,2], X[:,5], X[:,1],
                    alpha = 1,
                    c = kmeans.labels_,
                    cmap = cmap1,
                    marker ='^')
 
plt.title("K means(K=7)")
ax.set_xlabel('X', fontweight ='bold')
ax.set_ylabel('Y', fontweight ='bold')
ax.set_zlabel('Z', fontweight ='bold')
fig.colorbar(s, ax = ax, shrink = 0.5, aspect = 5)
plt.show()

# %%
# K= 20
kmeans = KMeans(n_clusters=20 , n_init=1).fit(X)
y_pred=kmeans.predict(X)

print('Adjusted rand score :', metrics.adjusted_rand_score(y, y_pred))
print('Normalized mutual information score :',metrics.normalized_mutual_info_score(y, y_pred))
print('Silhouette score :',metrics.silhouette_score(X, y_pred, metric='euclidean'))
print('Calinski harabasz score :',metrics.calinski_harabasz_score(X, y_pred))
print('Davies bouldin score', metrics.davies_bouldin_score(X, y_pred))
# Out:
# Adjusted rand score : 0.08486544058219903
# Normalized mutual information score : 0.23992664001958403
# Silhouette score : 0.38029453524301043
# Calinski harabasz score : 1242.9458834829816
# Davies bouldin score 0.8284276379263151

# %%
fig = plt.figure(figsize = (16, 9))
ax = plt.axes()
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.4, alpha = 0.2)
cmap1 = plt.get_cmap('tab20')
s = ax.scatter(X[:,2], X[:,5],
                    alpha = 1,
                    c = kmeans.labels_,
                    cmap = cmap1,
                    marker ='^')
 
plt.title("K means(K=20)")
ax.set_xlabel('X', fontweight ='bold')
ax.set_ylabel('Y', fontweight ='bold')

fig.colorbar(s, ax = ax, shrink = 0.5, aspect = 5)
plt.show()

# %%
fig = plt.figure(figsize = (16, 9))
ax = plt.axes(projection ="3d")
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.4, alpha = 0.2)
cmap1 = plt.get_cmap('tab20')
s = ax.scatter3D(X[:,2], X[:,5], X[:,1],
                    alpha = 1,
                    c = kmeans.labels_,
                    cmap = cmap1,
                    marker ='^')
 
plt.title("K means(K= 20)")
ax.set_xlabel('X', fontweight ='bold')
ax.set_ylabel('Y', fontweight ='bold')
ax.set_zlabel('Z', fontweight ='bold')
fig.colorbar(s, ax = ax, shrink = 0.5, aspect = 5)
plt.show()

# %%
# Agglomorative 
# Number = 2
AC = AgglomerativeClustering(n_clusters = 2).fit(X)
y_pred=AC.fit_predict(X)

print('Adjusted rand score :', metrics.adjusted_rand_score(y, y_pred))
print('Normalized mutual information score :',metrics.normalized_mutual_info_score(y, y_pred))
print('Silhouette score :',metrics.silhouette_score(X, y_pred, metric='euclidean'))
print('Calinski harabasz score :',metrics.calinski_harabasz_score(X, y_pred))
print('Davies bouldin score', metrics.davies_bouldin_score(X, y_pred))
# Out:
# Adjusted rand score : 0.0012681077088369456
# Normalized mutual information score : 0.003559021775499025
# Silhouette score : 0.41963257628878853
# Calinski harabasz score : 993.171502681194
# Davies bouldin score 0.7693036840890013

# %%
fig = plt.figure(figsize = (16, 9))
ax = plt.axes()
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.4, alpha = 0.2)
cmap1 = plt.get_cmap('Set1')
s = ax.scatter(X[:,2], X[:,5],
                    alpha = 1,
                    c = AC.labels_,
                    cmap = cmap1,
                    marker ='^')
 
plt.title("Agglomerative Clustering (No. of Clusters = 2)")
ax.set_xlabel('X', fontweight ='bold')
ax.set_ylabel('Y', fontweight ='bold')

fig.colorbar(s, ax = ax, shrink = 0.5, aspect = 5)
plt.show()

# %%
fig = plt.figure(figsize = (16, 9))
ax = plt.axes(projection ="3d")
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.4, alpha = 0.2)
cmap1 = plt.get_cmap('Set1')
s = ax.scatter3D(X[:,2], X[:,5], X[:,1],
                    alpha = 1,
                    c = AC.labels_,
                    cmap = cmap1,
                    marker ='^')
 
plt.title("Agglomerative Clustering (No. of Clusters = 2)")
ax.set_xlabel('X', fontweight ='bold')
ax.set_ylabel('Y', fontweight ='bold')
ax.set_zlabel('Z', fontweight ='bold')
fig.colorbar(s, ax = ax, shrink = 0.5, aspect = 5)
plt.show()

# %%
# Number = 7
AC = AgglomerativeClustering(n_clusters = 7).fit(X)
y_pred=AC.fit_predict(X)

print('Accuracy of Clustring :' , accuracy(y_pred, y))
print('Adjusted rand score :', metrics.adjusted_rand_score(y, y_pred))
print('Normalized mutual information score :',metrics.normalized_mutual_info_score(y, y_pred))
print('Silhouette score :',metrics.silhouette_score(X, y_pred, metric='euclidean'))
print('Calinski harabasz score :',metrics.calinski_harabasz_score(X, y_pred))
print('Davies bouldin score', metrics.davies_bouldin_score(X, y_pred))
# Out:
# Accuracy of Clustring : 12.146596858638743
# Adjusted rand score : 0.06402120762871498
# Normalized mutual information score : 0.12239701922736795
# Silhouette score : 0.3317432917651687
# Calinski harabasz score : 1068.8954820594267
# Davies bouldin score 0.9162986206276746

# %%
fig = plt.figure(figsize = (16, 9))
ax = plt.axes()
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.4, alpha = 0.2)
cmap1 = plt.get_cmap('Set1')
s = ax.scatter(X[:,2], X[:,5],
                    alpha = 1,
                    c = AC.labels_,
                    cmap = cmap1,
                    marker ='^')
 
plt.title("Agglomerative Clustering (No. of Clusters = 7)")
ax.set_xlabel('X', fontweight ='bold')
ax.set_ylabel('Y', fontweight ='bold')

fig.colorbar(s, ax = ax, shrink = 0.5, aspect = 5)
plt.show()

# %%
fig = plt.figure(figsize = (16, 9))
ax = plt.axes(projection ="3d")
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.4, alpha = 0.2)
cmap1 = plt.get_cmap('Set1')
s = ax.scatter3D(X[:,2], X[:,5], X[:,1],
                    alpha = 1,
                    c = AC.labels_,
                    cmap = cmap1,
                    marker ='^')
 
plt.title("Agglomerative Clustering (No. of Clusters = 7)")
ax.set_xlabel('X', fontweight ='bold')
ax.set_ylabel('Y', fontweight ='bold')
ax.set_zlabel('Z', fontweight ='bold')
fig.colorbar(s, ax = ax, shrink = 0.5, aspect = 5)
plt.show()

# %%
# Number = 20
AC = AgglomerativeClustering(n_clusters = 20).fit(X)
y_pred=AC.fit_predict(X)

print('Adjusted rand score :', metrics.adjusted_rand_score(y, y_pred))
print('Normalized mutual information score :',metrics.normalized_mutual_info_score(y, y_pred))
print('Silhouette score :',metrics.silhouette_score(X, y_pred, metric='euclidean'))
print('Calinski harabasz score :',metrics.calinski_harabasz_score(X, y_pred))
print('Davies bouldin score', metrics.davies_bouldin_score(X, y_pred))
# Out:
# Adjusted rand score : 0.09102395993169449
# Normalized mutual information score : 0.24504628065847484
# Silhouette score : 0.38405315646637006
# Calinski harabasz score : 1243.3888209420534
# Davies bouldin score 0.7977410883181444

# %%
fig = plt.figure(figsize = (16, 9))
ax = plt.axes()
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.4, alpha = 0.2)
cmap1 = plt.get_cmap('tab20')
s = ax.scatter(X[:,2], X[:,5],
                    alpha = 1,
                    c = AC.labels_,
                    cmap = cmap1,
                    marker ='^')
 
plt.title("Agglomerative Clustering (No. of Clusters = 20)")
ax.set_xlabel('X', fontweight ='bold')
ax.set_ylabel('Y', fontweight ='bold')

fig.colorbar(s, ax = ax, shrink = 0.5, aspect = 5)
plt.show()

# %%
fig = plt.figure(figsize = (16, 9))
ax = plt.axes(projection ="3d")
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.4, alpha = 0.2)
cmap1 = plt.get_cmap('tab20')
s = ax.scatter3D(X[:,2], X[:,5], X[:,1],
                    alpha = 1,
                    c = AC.labels_,
                    cmap = cmap1,
                    marker ='^')
 
plt.title("Agglomerative Clustering (No. of Clusters = 20)")
ax.set_xlabel('X', fontweight ='bold')
ax.set_ylabel('Y', fontweight ='bold')
ax.set_zlabel('Z', fontweight ='bold')
fig.colorbar(s, ax = ax, shrink = 0.5, aspect = 5)
plt.show()

# %%
hirarachical=linkage(X,method='complete')
dendrogram(hirarachical)
plt.show()
